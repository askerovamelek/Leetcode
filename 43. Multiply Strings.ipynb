# %%
class Solution:
    def multiply(self, num1: str, num2: str) -> str:
        a = []
        a.append(int(num1))   # burada int-ə çeviririk
        a.append(int(num2))
        return str(a[0] * a[1])
