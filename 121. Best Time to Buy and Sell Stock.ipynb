# %%
class Solution:
    def maxProfit(self, prices: List[int]) -> int:
        mini = prices[0]
        max_profit = 0
        
        for p in prices:
            if p < mini:
                mini = p
            else:
                max_profit = max(max_profit, p - mini)

        return max_profit
